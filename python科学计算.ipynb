# %% [markdown]
# 第1章

# %%
import numpy as np
import pandas as pd
import scipy as sp
import pylab as pl
# %matplotlib inline

# %%
x = np.linspace(0,4*np.pi,100)
pl.plot(x,np.sin(x))

# %% [markdown]
# 查看文档：
# - np.sin？表示查看函数的文档
# - np.sin?? 表示查看其Python源代码

# %%
np.sin?
n.sin??
help(np.sin)

# %%
import numpy as np
from scipy import signal
import pylab as pl

t = np.linspace(0,10,1000)
x = signal.chirp(t,5,10,30)
pl.plot(t,x)
pl.show()

# %%
x[:5]
# Out:
# array([ 1.        ,  0.95071557,  0.80679126,  0.58127309,  0.29581618])

# %%
pl.gca().lines[0].set_color('r')
pl.draw()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-600bbe5757a2> in <module>()
# ----> 1 pl.gca().lines[0].set_color('r')
#       2 pl.draw()
#
# IndexError: list index out of range

# %%
import pylab as pl
import numpy as np

def test_debug():
    x = np.linspace(1,50,10000)
    img = np.sin(x*np.cos(x))
    pl.imshow(img)
    pl.show()
test_debug()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a9c9edd05ba4> in <module>()
#       7     pl.imshow(img)
#       8     pl.show()
# ----> 9 test_debug()
#
# <ipython-input-14-a9c9edd05ba4> in test_debug()
#       5     x = np.linspace(1,50,10000)
#       6     img = np.sin(x*np.cos(x))
# ----> 7     pl.imshow(img)
#       8     pl.show()
#       9 test_debug()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3156                         filternorm=filternorm, filterrad=filterrad,
#    3157                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3158                         **kwargs)
#    3159     finally:
#    3160         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
#    1893         if pre_doc is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5116                               resample=resample, **kwargs)
#    5117
# -> 5118         im.set_data(X)
#    5119         im.set_alpha(alpha)
#    5120         if im.get_clip_path() is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     547         if (self._A.ndim not in (2, 3) or
#     548                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 549             raise TypeError("Invalid dimensions for image data")
#     550
#     551         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
x = np.linspace(1,50,10000)
img = np.sin(x*np.cos(x))
pl.imshow(img)
pl.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-7b8840a02462> in <module>()
#       1 x = np.linspace(1,50,10000)
#       2 img = np.sin(x*np.cos(x))
# ----> 3 pl.imshow(img)
#       4 pl.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3156                         filternorm=filternorm, filterrad=filterrad,
#    3157                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3158                         **kwargs)
#    3159     finally:
#    3160         ax._hold = washold
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
#    1889                     warnings.warn(msg % (label_namer, func.__name__),
#    1890                                   RuntimeWarning, stacklevel=2)
# -> 1891             return func(ax, *args, **kwargs)
#    1892         pre_doc = inner.__doc__
#    1893         if pre_doc is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5116                               resample=resample, **kwargs)
#    5117
# -> 5118         im.set_data(X)
#    5119         im.set_alpha(alpha)
#    5120         if im.get_clip_path() is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     547         if (self._A.ndim not in (2, 3) or
#     548                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 549             raise TypeError("Invalid dimensions for image data")
#     550
#     551         self._imcache = None
#
# TypeError: Invalid dimensions for image data

# %%
debug
# Out:
# > c:\programdata\anaconda3\lib\site-packages\matplotlib\image.py(549)set_data()
#     547         if (self._A.ndim not in (2, 3) or
#     548                 (self._A.ndim == 3 and self._A.shape[-1] not in (3, 4))):
# --> 549             raise TypeError("Invalid dimensions for image data")
#     550
#     551         self._imcache = None
#
# ipdb> h
#
# Documented commands (type help <topic>):
# ========================================
# EOF    c          d        h         next    pp       retval  u          whatis
# a      cl         debug    help      p       psource  run     unalias    where
# alias  clear      disable  ignore    pdef    q        rv      undisplay
# args   commands   display  interact  pdoc    quit     s       unt
# b      condition  down     j         pfile   r        source  until
# break  cont       enable   jump      pinfo   restart  step    up
# bt     continue   exit     n         pinfo2  return   tbreak  w
#
# Miscellaneous help topics:
# ==========================
# exec  pdb
#
# Undocumented commands:
# ======================
# l  list  ll  longlist
#
# ipdb> u
# > c:\programdata\anaconda3\lib\site-packages\matplotlib\axes\_axes.py(5118)imshow()
#    5116                               resample=resample, **kwargs)
#    5117
# -> 5118         im.set_data(X)
#    5119         im.set_alpha(alpha)
#    5120         if im.get_clip_path() is None:

# %%
img.ndim
